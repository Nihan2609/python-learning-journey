# %% [markdown]
# ### Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
## declare and assign varibles

age = 20
height = 5.11
name = "nihan"
is_student = true

## print 

print("age :",age)
print("Height : ",height)
print("Name :",name)
# Out:
# age : 20
# Height :  5.11
# Name : nihan

# %%
## Naming conventions
## variable name should be descriptive
## they must start with a or and underscrore '_' contain letter,number and underscroses
#variables name are case sensitive

## valid variable name

first_name = "Farhan"
last_name = "Nihan"

# %%
## invalid variable names 

#2age = 23
#first-name = "nihan"
#@name = "nihan"

# %%
## case sensitivity 

name = "nihan"
Name = "nihan"

# %%
## understanding variables types 
## puthon is dynamically typed, type of a variable is determined at runtime

age = 23 #int
height = 5.11 # float
name = "nihan" # str
is_student = True #bool

print (type(name))
# Out:
# <class 'str'>

# %%
## type checking and converstion

type (height)
# Out:
# float

# %%
age = 25 
print (type(age))
# Out:
# <class 'int'>

# %%
#type conversion 
age_str = str(age)
print (age_str)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
age = "25"
int (age)
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "Krish"
int (name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 name = "Krish"
# ----> 2 int (name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height = 5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
## dynamic typing
##python allows the type of a variable as the program executes 
var = 10 #int
print(var,type(var))

var = "hello"
print(var,type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input 

age = int (input("what is the age: "))
print(age)
print(age,type(age))
# Out:
# 15
# 15 <class 'int'>

# %%
#### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 20.0
# Difference: 0.0
# Product: 100.0
# Quotient: 1.0

# %% [markdown]
# ### Conclusion:
# Variables are essential in Python programming for storing and manipulating data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming conventions and understanding variable types will help in maintaining readability and consistency in your code.
